# %%
import requests
import numpy as np 
import pandas as pd 
import pickle    
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
color_map = plt.cm.winter
from matplotlib.patches import RegularPolygon
import math
from PIL import Image

'''
NHL API: https://gitlab.com/dword4/nhlapi/-/tree/master

More info: 

inspirations:
https://towardsdatascience.com/nhl-analytics-with-python-6390c5d3206d
https://towardsdatascience.com/python-hockey-analytics-tutorial-b0883085938a#ee0a
https://github.com/rkipp1210/data-projects/tree/master/hockey-shot-blocking
'''
url = "https://statsapi.web.nhl.com/api/v1/"
r = requests.get("https://statsapi.web.nhl.com/api/v1/teams/")

# %%
data = r.json()
df = pd.json_normalize(data["teams"])
team = df.loc[df.name == "Vancouver Canucks"]
df
# Out:
#     id                   name              link abbreviation        teamName  \
# 0    1      New Jersey Devils   /api/v1/teams/1          NJD          Devils
# 1    2     New York Islanders   /api/v1/teams/2          NYI       Islanders
# 2    3       New York Rangers   /api/v1/teams/3          NYR         Rangers
# 3    4    Philadelphia Flyers   /api/v1/teams/4          PHI          Flyers
# 4    5    Pittsburgh Penguins   /api/v1/teams/5          PIT        Penguins
# 5    6          Boston Bruins   /api/v1/teams/6          BOS          Bruins
# 6    7         Buffalo Sabres   /api/v1/teams/7          BUF          Sabres
# 7    8     Montréal Canadiens   /api/v1/teams/8          MTL       Canadiens
# 8    9        Ottawa Senators   /api/v1/teams/9          OTT        Senators
# 9   10    Toronto Maple Leafs  /api/v1/teams/10          TOR     Maple Leafs
# 10  12    Carolina Hurricanes  /api/v1/teams/12          CAR      Hurricanes
# 11  13       Florida Panthers  /api/v1/teams/13          FLA        Panthers
# 12  14    Tampa Bay Lightning  /api/v1/teams/14          TBL       Lightning
# 13  15    Washington Capitals  /api/v1/teams/15          WSH        Capitals
# 14  16     Chicago Blackhawks  /api/v1/teams/16          CHI      Blackhawks
# 15  17      Detroit Red Wings  /api/v1/teams/17          DET       Red Wings
# 16  18    Nashville Predators  /api/v1/teams/18          NSH       Predators
# 17  19        St. Louis Blues  /api/v1/teams/19          STL           Blues
# 18  20         Calgary Flames  /api/v1/teams/20          CGY          Flames
# 19  21     Colorado Avalanche  /api/v1/teams/21          COL       Avalanche
# 20  22        Edmonton Oilers  /api/v1/teams/22          EDM          Oilers
# 21  23      Vancouver Canucks  /api/v1/teams/23          VAN         Canucks
# 22  24          Anaheim Ducks  /api/v1/teams/24          ANA           Ducks
# 23  25           Dallas Stars  /api/v1/teams/25          DAL           Stars
# 24  26      Los Angeles Kings  /api/v1/teams/26          LAK           Kings
# 25  28        San Jose Sharks  /api/v1/teams/28          SJS          Sharks
# 26  29  Columbus Blue Jackets  /api/v1/teams/29          CBJ    Blue Jackets
# 27  30         Minnesota Wild  /api/v1/teams/30          MIN            Wild
# 28  52          Winnipeg Jets  /api/v1/teams/52          WPG            Jets
# 29  53        Arizona Coyotes  /api/v1/teams/53          ARI         Coyotes
# 30  54   Vegas Golden Knights  /api/v1/teams/54          VGK  Golden Knights
# 31  55         Seattle Kraken  /api/v1/teams/55          SEA          Kraken
# 31         https://www.nhl.com/seattle           39  ...                 PAC
#
#            division.link division.abbreviation conference.id conference.name  \
# 0   /api/v1/divisions/18                     M             6         Eastern
# 1   /api/v1/divisions/18                     M             6         Eastern
# 2   /api/v1/divisions/18                     M             6         Eastern
# 3   /api/v1/divisions/18                     M             6         Eastern
# 4   /api/v1/divisions/18                     M             6         Eastern
# 5   /api/v1/divisions/17                     A             6         Eastern
# 6   /api/v1/divisions/17                     A             6         Eastern
# 7   /api/v1/divisions/17                     A             6         Eastern
# 8   /api/v1/divisions/17                     A             6         Eastern
# 9   /api/v1/divisions/17                     A             6         Eastern
# 10  /api/v1/divisions/18                     M             6         Eastern
# 11  /api/v1/divisions/17                     A             6         Eastern
# 12  /api/v1/divisions/17                     A             6         Eastern
# 13  /api/v1/divisions/18                     M             6         Eastern
# 14  /api/v1/divisions/16                     C             5         Western
# 15  /api/v1/divisions/17                     A             6         Eastern
# 16  /api/v1/divisions/16                     C             5         Western
# 17  /api/v1/divisions/16                     C             5         Western
# 18  /api/v1/divisions/15                     P             5         Western
# 19  /api/v1/divisions/16                     C             5         Western
# 20  /api/v1/divisions/15                     P             5         Western
# 21  /api/v1/divisions/15                     P             5         Western
# 22  /api/v1/divisions/15                     P             5         Western
# 23  /api/v1/divisions/16                     C             5         Western
# 24  /api/v1/divisions/15                     P             5         Western
# 25  /api/v1/divisions/15                     P             5         Western
# 26  /api/v1/divisions/18                     M             6         Eastern
# 27  /api/v1/divisions/16                     C             5         Western
# 28  /api/v1/divisions/16                     C             5         Western
# 29  /api/v1/divisions/16                     C             5         Western
# 30  /api/v1/divisions/15                     P             5         Western
# 31  /api/v1/divisions/15                     P             5         Western
#
#           conference.link franchise.franchiseId  franchise.teamName  \
# 0   /api/v1/conferences/6                    23              Devils
# 1   /api/v1/conferences/6                    22           Islanders
# 2   /api/v1/conferences/6                    10             Rangers
# 3   /api/v1/conferences/6                    16              Flyers
# 4   /api/v1/conferences/6                    17            Penguins
# 5   /api/v1/conferences/6                     6              Bruins
# 6   /api/v1/conferences/6                    19              Sabres
# 7   /api/v1/conferences/6                     1           Canadiens
# 8   /api/v1/conferences/6                    30            Senators
# 9   /api/v1/conferences/6                     5         Maple Leafs
# 10  /api/v1/conferences/6                    26          Hurricanes
# 11  /api/v1/conferences/6                    33            Panthers
# 12  /api/v1/conferences/6                    31           Lightning
# 13  /api/v1/conferences/6                    24            Capitals
# 14  /api/v1/conferences/5                    11          Blackhawks
# 15  /api/v1/conferences/6                    12           Red Wings
# 16  /api/v1/conferences/5                    34           Predators
# 17  /api/v1/conferences/5                    18               Blues
# 18  /api/v1/conferences/5                    21              Flames
# 19  /api/v1/conferences/5                    27           Avalanche
# 20  /api/v1/conferences/5                    25              Oilers
# 21  /api/v1/conferences/5                    20             Canucks
# 22  /api/v1/conferences/5                    32               Ducks
# 23  /api/v1/conferences/5                    15               Stars
# 24  /api/v1/conferences/5                    14               Kings
# 25  /api/v1/conferences/5                    29              Sharks
# 26  /api/v1/conferences/6                    36        Blue Jackets
# 27  /api/v1/conferences/5                    37                Wild
# 28  /api/v1/conferences/5                    35                Jets
# 29  /api/v1/conferences/5                    28             Coyotes
# 30  /api/v1/conferences/5                    38      Golden Knights
# 31  /api/v1/conferences/5                    39              Kraken
#
#            franchise.link venue.id
# 0   /api/v1/franchises/23      NaN
# 1   /api/v1/franchises/22      NaN
# 2   /api/v1/franchises/10   5054.0
# 3   /api/v1/franchises/16   5096.0
# 4   /api/v1/franchises/17   5034.0
# 5    /api/v1/franchises/6   5085.0
# 6   /api/v1/franchises/19   5039.0
# 7    /api/v1/franchises/1   5028.0
# 8   /api/v1/franchises/30   5031.0
# 9    /api/v1/franchises/5      NaN
# 10  /api/v1/franchises/26   5066.0
# 11  /api/v1/franchises/33   5027.0
# 12  /api/v1/franchises/31      NaN
# 13  /api/v1/franchises/24   5094.0
# 14  /api/v1/franchises/11   5092.0
# 15  /api/v1/franchises/12   5145.0
# 16  /api/v1/franchises/34   5030.0
# 17  /api/v1/franchises/18   5076.0
# 18  /api/v1/franchises/21   5075.0
# 19  /api/v1/franchises/27   5064.0
# 20  /api/v1/franchises/25   5100.0
# 21  /api/v1/franchises/20   5073.0
# 22  /api/v1/franchises/32   5046.0
# 23  /api/v1/franchises/15   5019.0
# 24  /api/v1/franchises/14   5081.0
# 25  /api/v1/franchises/29      NaN
# 26  /api/v1/franchises/36   5059.0
# 27  /api/v1/franchises/37   5098.0
# 28  /api/v1/franchises/35   5058.0
# 29  /api/v1/franchises/28   5043.0
# 30  /api/v1/franchises/38   5178.0
# 31  /api/v1/franchises/39      NaN
#
# [32 rows x 29 columns]

# %%
seasons = "20182019"
r = requests.get(url + "schedule?season=" + seasons + "&gameType=R&site=en_nhl&teamId=" + '23')
data = r.json()
df = pd.DataFrame(data["dates"])
dates = df.date.tolist()
df
# Out:
#           date  totalItems  totalEvents  totalGames  totalMatches  \
# 0   2018-10-03           1            0           1             0
# 1   2018-10-06           1            0           1             0
# 2   2018-10-09           1            0           1             0
# 3   2018-10-11           1            0           1             0
# 4   2018-10-13           1            0           1             0
# ..         ...         ...          ...         ...           ...
# 77  2019-03-28           1            0           1             0
# 78  2019-03-30           1            0           1             0
# 79  2019-04-02           1            0           1             0
# 80  2019-04-04           1            0           1             0
# 81  2019-04-06           1            0           1             0
#
#                                                 games events matches
# 0   [{'gamePk': 2018020003, 'link': '/api/v1/game/...     []      []
# 1   [{'gamePk': 2018020028, 'link': '/api/v1/game/...     []      []
# 2   [{'gamePk': 2018020037, 'link': '/api/v1/game/...     []      []
# 3   [{'gamePk': 2018020053, 'link': '/api/v1/game/...     []      []
# 4   [{'gamePk': 2018020064, 'link': '/api/v1/game/...     []      []
# ..                                                ...    ...     ...
# 77  [{'gamePk': 2018021195, 'link': '/api/v1/game/...     []      []
# 78  [{'gamePk': 2018021213, 'link': '/api/v1/game/...     []      []
# 79  [{'gamePk': 2018021237, 'link': '/api/v1/game/...     []      []
# 80  [{'gamePk': 2018021249, 'link': '/api/v1/game/...     []      []
# 81  [{'gamePk': 2018021258, 'link': '/api/v1/game/...     []      []
#
# [82 rows x 8 columns]

# %%
gamedf = pd.DataFrame(df.games.tolist())
gamedf.columns= ['games']
gamedf
# Out:
#                                                 games
# 0   {'gamePk': 2018020003, 'link': '/api/v1/game/2...
# 1   {'gamePk': 2018020028, 'link': '/api/v1/game/2...
# 2   {'gamePk': 2018020037, 'link': '/api/v1/game/2...
# 3   {'gamePk': 2018020053, 'link': '/api/v1/game/2...
# 4   {'gamePk': 2018020064, 'link': '/api/v1/game/2...
# ..                                                ...
# 77  {'gamePk': 2018021195, 'link': '/api/v1/game/2...
# 78  {'gamePk': 2018021213, 'link': '/api/v1/game/2...
# 79  {'gamePk': 2018021237, 'link': '/api/v1/game/2...
# 80  {'gamePk': 2018021249, 'link': '/api/v1/game/2...
# 81  {'gamePk': 2018021258, 'link': '/api/v1/game/2...
#
# [82 rows x 1 columns]

# %%
gamedf = pd.json_normalize(gamedf.games)

# %%
gamedf = gamedf.loc[:, ['gamePk', 'link', 'gameType','season', 'status.abstractGameState']]
gamedf['date'] = dates
gamedf
# Out:
#         gamePk                               link gameType    season  \
# 0   2018020003  /api/v1/game/2018020003/feed/live        R  20182019
# 1   2018020028  /api/v1/game/2018020028/feed/live        R  20182019
# 2   2018020037  /api/v1/game/2018020037/feed/live        R  20182019
# 3   2018020053  /api/v1/game/2018020053/feed/live        R  20182019
# 4   2018020064  /api/v1/game/2018020064/feed/live        R  20182019
# ..         ...                                ...      ...       ...
# 77  2018021195  /api/v1/game/2018021195/feed/live        R  20182019
# 78  2018021213  /api/v1/game/2018021213/feed/live        R  20182019
# 79  2018021237  /api/v1/game/2018021237/feed/live        R  20182019
# 80  2018021249  /api/v1/game/2018021249/feed/live        R  20182019
# 81  2018021258  /api/v1/game/2018021258/feed/live        R  20182019
#
#    status.abstractGameState        date
# 0                     Final  2018-10-03
# 1                     Final  2018-10-06
# 2                     Final  2018-10-09
# 3                     Final  2018-10-11
# 4                     Final  2018-10-13
# ..                      ...         ...
# 77                    Final  2019-03-28
# 78                    Final  2019-03-30
# 79                    Final  2019-04-02
# 80                    Final  2019-04-04
# 81                    Final  2019-04-06
#
# [82 rows x 6 columns]

# %%
gamelinks = gamedf.link.tolist()

# %%
livedata = []

for gamelink in gamelinks:
    r = requests.get("https://statsapi.web.nhl.com" + gamelink)
    data = r.json()
    livedata.append(data)

# %%
'''
gamedata goes:
{
copyright
gamePk
link
metadata
gameData: {game, datetime, status, teams, players}
**liveData**: 
}

liveData goes: 
{
plays: {}
}'''
# Out:
# '\ngamedata goes:\n{\ncopyright\ngamePk\nlink\nmetadata\ngameData: {game, datetime, status, teams, players}\n**liveData**: \n}\n\nliveData goes: \n{\nplays: {}\n}'

# %%
# Initialise the player dictionary
full_name = 'Brock Boeser'
event_types = ['Shot','Goal']
player_data = {};
player_data['Shot'] = {};
player_data['Shot']['x'] = [];
player_data['Shot']['y'] = [];
player_data['Goal'] = {};
player_data['Goal']['x'] = [];
player_data['Goal']['y'] = [];

# %%
plays = 0
for data in livedata:
    if "liveData" not in data:
        continue
        
    # extract from playbyplay livedata
    plays = data['liveData']['plays']['allPlays']
    
    for play in plays:
        if "players" in play:
            for player in play["players"]:
                if player["player"]["fullName"] in [full_name] and player["playerType"] in ["Shooter", "Scorer"]:
                    
                    for event in event_types:
                        
                        #if play contains one of the events
                        if play["result"]["event"] in [event]:
                            
                            if "x" in play["coordinates"]:
                                player_data[event]["x"].append(play["coordinates"]["x"])
                                player_data[event]["y"].append(play["coordinates"]["y"])
                                
player_data
# Out:
# {'Shot': {'x': [82.0,
#    59.0,
#    -64.0,
#    51.0,
#    48.0,
#    -52.0,
#    45.0,
#    -19.0,
#    -47.0,
#    -48.0,
#    72.0,
#    -86.0,
#    -36.0,
#    -79.0,
#    61.0,
#    -60.0,
#    -86.0,
#    -53.0,
#    -61.0,
#    -51.0,
#    55.0,
#    57.0,
#    -53.0,
#    43.0,
#    61.0,
#    56.0,
#    -72.0,
#    -81.0,
#    -59.0,
#    -77.0,
#    -45.0,
#    -66.0,
#    57.0,
#    -59.0,
#    22.0,
#    43.0,
#    69.0,
#    42.0,
#    62.0,
#    57.0,
#    70.0,
#    72.0,
#    53.0,
#    57.0,
#    -76.0,
#    -53.0,
#    -76.0,
#    -81.0,
#    -70.0,
#    48.0,
#    -77.0,
#    73.0,
#    -41.0,
#    -75.0,
#    -26.0,
#    64.0,
#    -40.0,
#    35.0,
#    73.0,
#    -55.0,
#    36.0,
#    -75.0,
#    58.0,
#    60.0,
#    -81.0,
#    -60.0,
#    -50.0,
#    -74.0,
#    61.0,
#    -50.0,
#    -31.0,
#    -79.0,
#    79.0,
#    -79.0,
#    -85.0,
#    -64.0,
#    -64.0,
#    85.0,
#    95.0,
#    32.0,
#    59.0,
#    61.0,
#    61.0,
#    72.0,
#    74.0,
#    82.0,
#    -52.0,
#    -85.0,
#    76.0,
#    -77.0,
#    -72.0,
#    67.0,
#    -67.0,
#    -72.0,
#    74.0,
#    48.0,
#    -31.0,
#    59.0,
#    71.0,
#    -52.0,
#    -55.0,
#    17.0,
#    54.0,
#    36.0,
#    66.0,
#    -78.0,
#    -82.0,
#    -65.0,
#    -73.0,
#    75.0,
#    38.0,
#    -61.0,
#    -54.0,
#    -78.0,
#    67.0,
#    -56.0,
#    78.0,
#    -79.0,
#    -55.0,
#    56.0,
#    -69.0,
#    40.0,
#    -87.0,
#    -54.0,
#    62.0,
#    81.0,
#    -61.0,
#    63.0,
#    72.0,
#    -81.0,
#    -64.0,
#    -33.0,
#    -55.0,
#    -45.0,
#    -43.0,
#    48.0,
#    -49.0,
#    -78.0,
#    -43.0,
#    -69.0,
#    73.0,
#    -51.0,
#    -55.0,
#    39.0,
#    -58.0,
#    -50.0,
#    -34.0,
#    -58.0,
#    39.0,
#    78.0,
#    -63.0,
#    61.0,
#    -84.0,
#    48.0,
#    6.0,
#    -17.0,
#    2.0,
#    19.0,
#    -30.0,
#    -19.0,
#    1.0,
#    -5.0,
#    -11.0,
#    -19.0,
#    7.0,
#    -16.0,
#    5.0,
#    6.0,
#    -31.0,
#    33.0,
#    -7.0,
#    -8.0,
#    5.0]},
#  'Goal': {'x': [-43.0,
#    66.0,
#    -78.0,
#    61.0,
#    -78.0,
#    -78.0,
#    -63.0,
#    -69.0,
#    -45.0,
#    -54.0,
#    35.0,
#    56.0,
#    -76.0,
#    66.0,
#    -68.0,
#    84.0,
#    39.0,
#    -49.0,
#    63.0,
#    -82.0,
#    75.0,
#    -81.0,
#    60.0,
#    -75.0,
#    60.0,
#    54.0,
#    -47.0,
#    80.0],
#   'y': [23.0,
#    18.0,
#    -1.0,
#    8.0,
#    1.0,
#    -7.0,
#    4.0,
#    3.0,
#    0.0,
#    -22.0,
#    -4.0,
#    -22.0,
#    7.0,
#    -14.0,
#    19.0,
#    -7.0,
#    16.0,
#    36.0,
#    20.0,
#    11.0,
#    -1.0,
#    -6.0,
#    8.0,
#    0.0,
#    12.0,
#    -21.0,
#    6.0,
#    -10.0]}}

# %%
playdf = pd.DataFrame(plays)
pd.set_option('display.max_rows', None)
playdf
# Out:
#                                                 result  \
# 0    {'event': 'Game Scheduled', 'eventCode': 'STL1...
# 1    {'event': 'Period Ready', 'eventCode': 'STL5',...
# 2    {'event': 'Period Start', 'eventCode': 'STL51'...
# 3    {'event': 'Faceoff', 'eventCode': 'STL52', 'ev...
# 4    {'event': 'Shot', 'eventCode': 'STL53', 'event...
# 5    {'event': 'Stoppage', 'eventCode': 'STL8', 'ev...
# 6    {'event': 'Faceoff', 'eventCode': 'STL54', 'ev...
# 7    {'event': 'Hit', 'eventCode': 'STL9', 'eventTy...
# 8    {'event': 'Stoppage', 'eventCode': 'STL10', 'e...
# 9    {'event': 'Faceoff', 'eventCode': 'STL55', 'ev...
# 10   {'event': 'Missed Shot', 'eventCode': 'STL56',...
# 11   {'event': 'Shot', 'eventCode': 'STL57', 'event...
# 12   {'event': 'Hit', 'eventCode': 'STL11', 'eventT...
# 13   {'event': 'Blocked Shot', 'eventCode': 'STL58'...
# 14   {'event': 'Giveaway', 'eventCode': 'STL12', 'e...
# 15   {'event': 'Stoppage', 'eventCode': 'STL13', 'e...
# 16   {'event': 'Faceoff', 'eventCode': 'STL59', 'ev...
# 17   {'event': 'Shot', 'eventCode': 'STL60', 'event...
# 18   {'event': 'Stoppage', 'eventCode': 'STL14', 'e...
# 19   {'event': 'Faceoff', 'eventCode': 'STL61', 'ev...
# 20   {'event': 'Blocked Shot', 'eventCode': 'STL62'...
# 21   {'event': 'Shot', 'eventCode': 'STL63', 'event...
# 22   {'event': 'Shot', 'eventCode': 'STL64', 'event...
# 23   {'event': 'Blocked Shot', 'eventCode': 'STL65'...
# 24   {'event': 'Stoppage', 'eventCode': 'STL15', 'e...
# 25   {'event': 'Faceoff', 'eventCode': 'STL66', 'ev...
# 257  {'event': 'Takeaway', 'eventCode': 'STL561', '...
# 258  {'event': 'Period End', 'eventCode': 'STL562',...
# 259  {'event': 'Period Official', 'eventCode': 'STL...
# 260  {'event': 'Period Ready', 'eventCode': 'STL566...
# 261  {'event': 'Period Start', 'eventCode': 'STL669...
# 262  {'event': 'Faceoff', 'eventCode': 'STL670', 'e...
# 263  {'event': 'Shot', 'eventCode': 'STL671', 'even...
# 264  {'event': 'Takeaway', 'eventCode': 'STL567', '...
# 265  {'event': 'Shot', 'eventCode': 'STL672', 'even...
# 266  {'event': 'Stoppage', 'eventCode': 'STL568', '...
# 267  {'event': 'Faceoff', 'eventCode': 'STL673', 'e...
# 268  {'event': 'Blocked Shot', 'eventCode': 'STL674...
# 269  {'event': 'Takeaway', 'eventCode': 'STL569', '...
# 270  {'event': 'Shot', 'eventCode': 'STL675', 'even...
# 271  {'event': 'Stoppage', 'eventCode': 'STL570', '...
# 272  {'event': 'Faceoff', 'eventCode': 'STL676', 'e...
# 273  {'event': 'Missed Shot', 'eventCode': 'STL677'...
# 274  {'event': 'Shot', 'eventCode': 'STL678', 'even...
# 275  {'event': 'Penalty', 'eventCode': 'STL571', 'e...
# 276  {'event': 'Faceoff', 'eventCode': 'STL679', 'e...
# 277  {'event': 'Shot', 'eventCode': 'STL680', 'even...
# 278  {'event': 'Stoppage', 'eventCode': 'STL573', '...
# 279  {'event': 'Faceoff', 'eventCode': 'STL681', 'e...
# 280  {'event': 'Blocked Shot', 'eventCode': 'STL682...
# 281  {'event': 'Shot', 'eventCode': 'STL683', 'even...
# 282  {'event': 'Stoppage', 'eventCode': 'STL574', '...
# 283  {'event': 'Faceoff', 'eventCode': 'STL684', 'e...
# 284  {'event': 'Missed Shot', 'eventCode': 'STL685'...
# 285  {'event': 'Blocked Shot', 'eventCode': 'STL686...
# 286  {'event': 'Shot', 'eventCode': 'STL687', 'even...
# 287  {'event': 'Shot', 'eventCode': 'STL689', 'even...
# 288  {'event': 'Period End', 'eventCode': 'STL575',...
# 289  {'event': 'Period Official', 'eventCode': 'STL...
# 290  {'event': 'Period Ready', 'eventCode': 'STL579...
# 291  {'event': 'Period Start', 'eventCode': 'STL580...
# 292  {'event': 'Goal', 'eventCode': 'STL690', 'even...
# 293  {'event': 'Shot', 'eventCode': 'STL691', 'even...
# 294  {'event': 'Goal', 'eventCode': 'STL692', 'even...
# 295  {'event': 'Shot', 'eventCode': 'STL693', 'even...
# 296  {'event': 'Shootout Complete', 'eventCode': 'S...
# 297  {'event': 'Period End', 'eventCode': 'STL581',...
# 298  {'event': 'Period Official', 'eventCode': 'STL...
# 299  {'event': 'Game End', 'eventCode': 'STL585', '...
#
#                                                  about  \
# 0    {'eventIdx': 0, 'eventId': 1, 'period': 1, 'pe...
# 1    {'eventIdx': 1, 'eventId': 5, 'period': 1, 'pe...
# 2    {'eventIdx': 2, 'eventId': 51, 'period': 1, 'p...
# 3    {'eventIdx': 3, 'eventId': 52, 'period': 1, 'p...
# 4    {'eventIdx': 4, 'eventId': 53, 'period': 1, 'p...
# 5    {'eventIdx': 5, 'eventId': 8, 'period': 1, 'pe...
# 6    {'eventIdx': 6, 'eventId': 54, 'period': 1, 'p...
# 7    {'eventIdx': 7, 'eventId': 9, 'period': 1, 'pe...
# 8    {'eventIdx': 8, 'eventId': 10, 'period': 1, 'p...
# 9    {'eventIdx': 9, 'eventId': 55, 'period': 1, 'p...
# 10   {'eventIdx': 10, 'eventId': 56, 'period': 1, '...
# 11   {'eventIdx': 11, 'eventId': 57, 'period': 1, '...
# 12   {'eventIdx': 12, 'eventId': 11, 'period': 1, '...
# 13   {'eventIdx': 13, 'eventId': 58, 'period': 1, '...
# 14   {'eventIdx': 14, 'eventId': 12, 'period': 1, '...
# 15   {'eventIdx': 15, 'eventId': 13, 'period': 1, '...
# 16   {'eventIdx': 16, 'eventId': 59, 'period': 1, '...
# 17   {'eventIdx': 17, 'eventId': 60, 'period': 1, '...
# 18   {'eventIdx': 18, 'eventId': 14, 'period': 1, '...
# 19   {'eventIdx': 19, 'eventId': 61, 'period': 1, '...
# 20   {'eventIdx': 20, 'eventId': 62, 'period': 1, '...
# 21   {'eventIdx': 21, 'eventId': 63, 'period': 1, '...
# 22   {'eventIdx': 22, 'eventId': 64, 'period': 1, '...
# 23   {'eventIdx': 23, 'eventId': 65, 'period': 1, '...
# 24   {'eventIdx': 24, 'eventId': 15, 'period': 1, '...
# 25   {'eventIdx': 25, 'eventId': 66, 'period': 1, '...
# 26   {'eventIdx': 26, 'eventId': 67, 'period': 1, '...
# 27   {'eventIdx': 27, 'eventId': 68, 'period': 1, '...
# 28   {'eventIdx': 28, 'eventId': 69, 'period': 1, '...
# 29   {'eventIdx': 29, 'eventId': 70, 'period': 1, '...
# 30   {'eventIdx': 30, 'eventId': 71, 'period': 1, '...
# 31   {'eventIdx': 31, 'eventId': 16, 'period': 1, '...
# 32   {'eventIdx': 32, 'eventId': 17, 'period': 1, '...
# 33   {'eventIdx': 33, 'eventId': 72, 'period': 1, '...
# 34   {'eventIdx': 34, 'eventId': 73, 'period': 1, '...
# 35   {'eventIdx': 35, 'eventId': 74, 'period': 1, '...
# 36   {'eventIdx': 36, 'eventId': 18, 'period': 1, '...
# 37   {'eventIdx': 37, 'eventId': 19, 'period': 1, '...
# 38   {'eventIdx': 38, 'eventId': 75, 'period': 1, '...
# 39   {'eventIdx': 39, 'eventId': 20, 'period': 1, '...
# 40   {'eventIdx': 40, 'eventId': 21, 'period': 1, '...
# 41   {'eventIdx': 41, 'eventId': 76, 'period': 1, '...
# 42   {'eventIdx': 42, 'eventId': 22, 'period': 1, '...
# 43   {'eventIdx': 43, 'eventId': 77, 'period': 1, '...
# 44   {'eventIdx': 44, 'eventId': 23, 'period': 1, '...
# 45   {'eventIdx': 45, 'eventId': 24, 'period': 1, '...
# 46   {'eventIdx': 46, 'eventId': 78, 'period': 1, '...
# 47   {'eventIdx': 47, 'eventId': 25, 'period': 1, '...
# 48   {'eventIdx': 48, 'eventId': 79, 'period': 1, '...
# 49   {'eventIdx': 49, 'eventId': 80, 'period': 1, '...
# 50   {'eventIdx': 50, 'eventId': 26, 'period': 1, '...
# 51   {'eventIdx': 51, 'eventId': 81, 'period': 1, '...
# 52   {'eventIdx': 52, 'eventId': 82, 'period': 1, '...
# 53   {'eventIdx': 53, 'eventId': 83, 'period': 1, '...
# 54   {'eventIdx': 54, 'eventId': 27, 'period': 1, '...
# 55   {'eventIdx': 55, 'eventId': 84, 'period': 1, '...
# 56   {'eventIdx': 56, 'eventId': 28, 'period': 1, '...
# 57   {'eventIdx': 57, 'eventId': 85, 'period': 1, '...
# 58   {'eventIdx': 58, 'eventId': 86, 'period': 1, '...
# 59   {'eventIdx': 59, 'eventId': 87, 'period': 1, '...
# 60   {'eventIdx': 60, 'eventId': 88, 'period': 1, '...
# 61   {'eventIdx': 61, 'eventId': 29, 'period': 1, '...
# 62   {'eventIdx': 62, 'eventId': 89, 'period': 1, '...
# 63   {'eventIdx': 63, 'eventId': 30, 'period': 1, '...
# 64   {'eventIdx': 64, 'eventId': 90, 'period': 1, '...
# 65   {'eventIdx': 65, 'eventId': 31, 'period': 1, '...
# 66   {'eventIdx': 66, 'eventId': 32, 'period': 1, '...
# 67   {'eventIdx': 67, 'eventId': 92, 'period': 1, '...
# 68   {'eventIdx': 68, 'eventId': 33, 'period': 1, '...
# 69   {'eventIdx': 69, 'eventId': 93, 'period': 1, '...
# 70   {'eventIdx': 70, 'eventId': 94, 'period': 1, '...
# 71   {'eventIdx': 71, 'eventId': 95, 'period': 1, '...
# 72   {'eventIdx': 72, 'eventId': 96, 'period': 1, '...
# 73   {'eventIdx': 73, 'eventId': 97, 'period': 1, '...
# 74   {'eventIdx': 74, 'eventId': 35, 'period': 1, '...
# 75   {'eventIdx': 75, 'eventId': 98, 'period': 1, '...
# 76   {'eventIdx': 76, 'eventId': 36, 'period': 1, '...
# 77   {'eventIdx': 77, 'eventId': 37, 'period': 1, '...
# 78   {'eventIdx': 78, 'eventId': 99, 'period': 1, '...
# 79   {'eventIdx': 79, 'eventId': 38, 'period': 1, '...
# 80   {'eventIdx': 80, 'eventId': 100, 'period': 1, ...
# 81   {'eventIdx': 81, 'eventId': 201, 'period': 1, ...
# 82   {'eventIdx': 82, 'eventId': 202, 'period': 1, ...
# 83   {'eventIdx': 83, 'eventId': 203, 'period': 1, ...
# 84   {'eventIdx': 84, 'eventId': 40, 'period': 1, '...
# 85   {'eventIdx': 85, 'eventId': 204, 'period': 1, ...
# 86   {'eventIdx': 86, 'eventId': 205, 'period': 1, ...
# 87   {'eventIdx': 87, 'eventId': 41, 'period': 1, '...
# 88   {'eventIdx': 88, 'eventId': 44, 'period': 1, '...
# 89   {'eventIdx': 89, 'eventId': 45, 'period': 2, '...
# 90   {'eventIdx': 90, 'eventId': 206, 'period': 2, ...
# 91   {'eventIdx': 91, 'eventId': 207, 'period': 2, ...
# 92   {'eventIdx': 92, 'eventId': 46, 'period': 2, '...
# 93   {'eventIdx': 93, 'eventId': 208, 'period': 2, ...
# 94   {'eventIdx': 94, 'eventId': 47, 'period': 2, '...
# 95   {'eventIdx': 95, 'eventId': 209, 'period': 2, ...
# 96   {'eventIdx': 96, 'eventId': 210, 'period': 2, ...
# 97   {'eventIdx': 97, 'eventId': 212, 'period': 2, ...
# 98   {'eventIdx': 98, 'eventId': 213, 'period': 2, ...
# 99   {'eventIdx': 99, 'eventId': 214, 'period': 2, ...
# 100  {'eventIdx': 100, 'eventId': 215, 'period': 2,...
# 101  {'eventIdx': 101, 'eventId': 48, 'period': 2, ...
# 102  {'eventIdx': 102, 'eventId': 216, 'period': 2,...
# 103  {'eventIdx': 103, 'eventId': 49, 'period': 2, ...
# 104  {'eventIdx': 104, 'eventId': 217, 'period': 2,...
# 105  {'eventIdx': 105, 'eventId': 50, 'period': 2, ...
# 106  {'eventIdx': 106, 'eventId': 218, 'period': 2,...
# 107  {'eventIdx': 107, 'eventId': 219, 'period': 2,...
# 108  {'eventIdx': 108, 'eventId': 351, 'period': 2,...
# 109  {'eventIdx': 109, 'eventId': 220, 'period': 2,...
# 110  {'eventIdx': 110, 'eventId': 221, 'period': 2,...
# 111  {'eventIdx': 111, 'eventId': 222, 'period': 2,...
# 112  {'eventIdx': 112, 'eventId': 352, 'period': 2,...
# 113  {'eventIdx': 113, 'eventId': 353, 'period': 2,...
# 114  {'eventIdx': 114, 'eventId': 354, 'period': 2,...
# 115  {'eventIdx': 115, 'eventId': 355, 'period': 2,...
# 116  {'eventIdx': 116, 'eventId': 223, 'period': 2,...
# 117  {'eventIdx': 117, 'eventId': 224, 'period': 2,...
# 118  {'eventIdx': 118, 'eventId': 356, 'period': 2,...
# 119  {'eventIdx': 119, 'eventId': 225, 'period': 2,...
# 120  {'eventIdx': 120, 'eventId': 357, 'period': 2,...
# 121  {'eventIdx': 121, 'eventId': 358, 'period': 2,...
# 122  {'eventIdx': 122, 'eventId': 226, 'period': 2,...
# 123  {'eventIdx': 123, 'eventId': 359, 'period': 2,...
# 124  {'eventIdx': 124, 'eventId': 227, 'period': 2,...
# 125  {'eventIdx': 125, 'eventId': 360, 'period': 2,...
# 126  {'eventIdx': 126, 'eventId': 228, 'period': 2,...
# 127  {'eventIdx': 127, 'eventId': 229, 'period': 2,...
# 128  {'eventIdx': 128, 'eventId': 362, 'period': 2,...
# 129  {'eventIdx': 129, 'eventId': 230, 'period': 2,...
# 130  {'eventIdx': 130, 'eventId': 363, 'period': 2,...
# 131  {'eventIdx': 131, 'eventId': 231, 'period': 2,...
# 132  {'eventIdx': 132, 'eventId': 232, 'period': 2,...
# 133  {'eventIdx': 133, 'eventId': 233, 'period': 2,...
# 134  {'eventIdx': 134, 'eventId': 364, 'period': 2,...
# 135  {'eventIdx': 135, 'eventId': 234, 'period': 2,...
# 136  {'eventIdx': 136, 'eventId': 235, 'period': 2,...
# 137  {'eventIdx': 137, 'eventId': 237, 'period': 2,...
# 138  {'eventIdx': 138, 'eventId': 365, 'period': 2,...
# 139  {'eventIdx': 139, 'eventId': 238, 'period': 2,...
# 140  {'eventIdx': 140, 'eventId': 239, 'period': 2,...
# 141  {'eventIdx': 141, 'eventId': 366, 'period': 2,...
# 142  {'eventIdx': 142, 'eventId': 240, 'period': 2,...
# 143  {'eventIdx': 143, 'eventId': 241, 'period': 2,...
# 144  {'eventIdx': 144, 'eventId': 242, 'period': 2,...
# 145  {'eventIdx': 145, 'eventId': 367, 'period': 2,...
# 146  {'eventIdx': 146, 'eventId': 243, 'period': 2,...
# 147  {'eventIdx': 147, 'eventId': 368, 'period': 2,...
# 148  {'eventIdx': 148, 'eventId': 244, 'period': 2,...
# 149  {'eventIdx': 149, 'eventId': 245, 'period': 2,...
# 150  {'eventIdx': 150, 'eventId': 369, 'period': 2,...
# 151  {'eventIdx': 151, 'eventId': 370, 'period': 2,...
# 152  {'eventIdx': 152, 'eventId': 371, 'period': 2,...
# 153  {'eventIdx': 153, 'eventId': 246, 'period': 2,...
# 154  {'eventIdx': 154, 'eventId': 372, 'period': 2,...
# 155  {'eventIdx': 155, 'eventId': 247, 'period': 2,...
# 156  {'eventIdx': 156, 'eventId': 373, 'period': 2,...
# 157  {'eventIdx': 157, 'eventId': 249, 'period': 2,...
# 158  {'eventIdx': 158, 'eventId': 451, 'period': 2,...
# 159  {'eventIdx': 159, 'eventId': 250, 'period': 2,...
# 160  {'eventIdx': 160, 'eventId': 374, 'period': 2,...
# 161  {'eventIdx': 161, 'eventId': 377, 'period': 2,...
# 162  {'eventIdx': 162, 'eventId': 378, 'period': 3,...
# 163  {'eventIdx': 163, 'eventId': 452, 'period': 3,...
# 164  {'eventIdx': 164, 'eventId': 453, 'period': 3,...
# 165  {'eventIdx': 165, 'eventId': 379, 'period': 3,...
# 166  {'eventIdx': 166, 'eventId': 454, 'period': 3,...
# 167  {'eventIdx': 167, 'eventId': 455, 'period': 3,...
# 168  {'eventIdx': 168, 'eventId': 456, 'period': 3,...
# 169  {'eventIdx': 169, 'eventId': 457, 'period': 3,...
# 170  {'eventIdx': 170, 'eventId': 380, 'period': 3,...
# 171  {'eventIdx': 171, 'eventId': 458, 'period': 3,...
# 172  {'eventIdx': 172, 'eventId': 459, 'period': 3,...
# 173  {'eventIdx': 173, 'eventId': 381, 'period': 3,...
# 174  {'eventIdx': 174, 'eventId': 460, 'period': 3,...
# 175  {'eventIdx': 175, 'eventId': 461, 'period': 3,...
# 176  {'eventIdx': 176, 'eventId': 462, 'period': 3,...
# 177  {'eventIdx': 177, 'eventId': 463, 'period': 3,...
# 178  {'eventIdx': 178, 'eventId': 464, 'period': 3,...
# 179  {'eventIdx': 179, 'eventId': 465, 'period': 3,...
# 180  {'eventIdx': 180, 'eventId': 466, 'period': 3,...
# 181  {'eventIdx': 181, 'eventId': 383, 'period': 3,...
# 182  {'eventIdx': 182, 'eventId': 467, 'period': 3,...
# 183  {'eventIdx': 183, 'eventId': 384, 'period': 3,...
# 184  {'eventIdx': 184, 'eventId': 468, 'period': 3,...
# 185  {'eventIdx': 185, 'eventId': 469, 'period': 3,...
# 186  {'eventIdx': 186, 'eventId': 385, 'period': 3,...
# 187  {'eventIdx': 187, 'eventId': 470, 'period': 3,...
# 188  {'eventIdx': 188, 'eventId': 471, 'period': 3,...
# 189  {'eventIdx': 189, 'eventId': 386, 'period': 3,...
# 190  {'eventIdx': 190, 'eventId': 472, 'period': 3,...
# 191  {'eventIdx': 191, 'eventId': 387, 'period': 3,...
# 192  {'eventIdx': 192, 'eventId': 388, 'period': 3,...
# 193  {'eventIdx': 193, 'eventId': 473, 'period': 3,...
# 194  {'eventIdx': 194, 'eventId': 474, 'period': 3,...
# 195  {'eventIdx': 195, 'eventId': 475, 'period': 3,...
# 196  {'eventIdx': 196, 'eventId': 476, 'period': 3,...
# 197  {'eventIdx': 197, 'eventId': 477, 'period': 3,...
# 198  {'eventIdx': 198, 'eventId': 478, 'period': 3,...
# 199  {'eventIdx': 199, 'eventId': 479, 'period': 3,...
# 200  {'eventIdx': 200, 'eventId': 389, 'period': 3,...
# 201  {'eventIdx': 201, 'eventId': 480, 'period': 3,...
# 202  {'eventIdx': 202, 'eventId': 390, 'period': 3,...
# 203  {'eventIdx': 203, 'eventId': 481, 'period': 3,...
# 204  {'eventIdx': 204, 'eventId': 482, 'period': 3,...
# 205  {'eventIdx': 205, 'eventId': 391, 'period': 3,...
# 206  {'eventIdx': 206, 'eventId': 483, 'period': 3,...
# 207  {'eventIdx': 207, 'eventId': 484, 'period': 3,...
# 208  {'eventIdx': 208, 'eventId': 485, 'period': 3,...
# 209  {'eventIdx': 209, 'eventId': 486, 'period': 3,...
# 210  {'eventIdx': 210, 'eventId': 393, 'period': 3,...
# 211  {'eventIdx': 211, 'eventId': 487, 'period': 3,...
# 212  {'eventIdx': 212, 'eventId': 488, 'period': 3,...
# 213  {'eventIdx': 213, 'eventId': 489, 'period': 3,...
# 214  {'eventIdx': 214, 'eventId': 394, 'period': 3,...
# 215  {'eventIdx': 215, 'eventId': 490, 'period': 3,...
# 216  {'eventIdx': 216, 'eventId': 395, 'period': 3,...
# 217  {'eventIdx': 217, 'eventId': 396, 'period': 3,...
# 218  {'eventIdx': 218, 'eventId': 491, 'period': 3,...
# 219  {'eventIdx': 219, 'eventId': 397, 'period': 3,...
# 220  {'eventIdx': 220, 'eventId': 492, 'period': 3,...
# 221  {'eventIdx': 221, 'eventId': 398, 'period': 3,...
# 222  {'eventIdx': 222, 'eventId': 493, 'period': 3,...
# 223  {'eventIdx': 223, 'eventId': 399, 'period': 3,...
# 224  {'eventIdx': 224, 'eventId': 494, 'period': 3,...
# 225  {'eventIdx': 225, 'eventId': 400, 'period': 3,...
# 226  {'eventIdx': 226, 'eventId': 495, 'period': 3,...
# 227  {'eventIdx': 227, 'eventId': 551, 'period': 3,...
# 228  {'eventIdx': 228, 'eventId': 496, 'period': 3,...
# 229  {'eventIdx': 229, 'eventId': 552, 'period': 3,...
# 230  {'eventIdx': 230, 'eventId': 553, 'period': 3,...
# 231  {'eventIdx': 231, 'eventId': 497, 'period': 3,...
# 232  {'eventIdx': 232, 'eventId': 498, 'period': 3,...
# 233  {'eventIdx': 233, 'eventId': 499, 'period': 3,...
# 234  {'eventIdx': 234, 'eventId': 500, 'period': 3,...
# 235  {'eventIdx': 235, 'eventId': 652, 'period': 3,...
# 236  {'eventIdx': 236, 'eventId': 554, 'period': 3,...
# 237  {'eventIdx': 237, 'eventId': 555, 'period': 3,...
# 238  {'eventIdx': 238, 'eventId': 653, 'period': 3,...
# 239  {'eventIdx': 239, 'eventId': 557, 'period': 3,...
# 240  {'eventIdx': 240, 'eventId': 654, 'period': 3,...
# 241  {'eventIdx': 241, 'eventId': 655, 'period': 3,...
# 242  {'eventIdx': 242, 'eventId': 656, 'period': 3,...
# 243  {'eventIdx': 243, 'eventId': 657, 'period': 3,...
# 244  {'eventIdx': 244, 'eventId': 658, 'period': 3,...
# 245  {'eventIdx': 245, 'eventId': 659, 'period': 3,...
# 246  {'eventIdx': 246, 'eventId': 558, 'period': 3,...
# 247  {'eventIdx': 247, 'eventId': 660, 'period': 3,...
# 248  {'eventIdx': 248, 'eventId': 661, 'period': 3,...
# 249  {'eventIdx': 249, 'eventId': 662, 'period': 3,...
# 250  {'eventIdx': 250, 'eventId': 663, 'period': 3,...
# 251  {'eventIdx': 251, 'eventId': 664, 'period': 3,...
# 252  {'eventIdx': 252, 'eventId': 559, 'period': 3,...
# 253  {'eventIdx': 253, 'eventId': 665, 'period': 3,...
# 254  {'eventIdx': 254, 'eventId': 666, 'period': 3,...
# 255  {'eventIdx': 255, 'eventId': 560, 'period': 3,...
# 256  {'eventIdx': 256, 'eventId': 668, 'period': 3,...
# 257  {'eventIdx': 257, 'eventId': 561, 'period': 3,...
# 258  {'eventIdx': 258, 'eventId': 562, 'period': 3,...
# 259  {'eventIdx': 259, 'eventId': 565, 'period': 3,...
# 260  {'eventIdx': 260, 'eventId': 566, 'period': 4,...
# 261  {'eventIdx': 261, 'eventId': 669, 'period': 4,...
# 262  {'eventIdx': 262, 'eventId': 670, 'period': 4,...
# 263  {'eventIdx': 263, 'eventId': 671, 'period': 4,...
# 264  {'eventIdx': 264, 'eventId': 567, 'period': 4,...
# 265  {'eventIdx': 265, 'eventId': 672, 'period': 4,...
# 266  {'eventIdx': 266, 'eventId': 568, 'period': 4,...
# 267  {'eventIdx': 267, 'eventId': 673, 'period': 4,...
# 268  {'eventIdx': 268, 'eventId': 674, 'period': 4,...
# 269  {'eventIdx': 269, 'eventId': 569, 'period': 4,...
# 270  {'eventIdx': 270, 'eventId': 675, 'period': 4,...
# 271  {'eventIdx': 271, 'eventId': 570, 'period': 4,...
# 272  {'eventIdx': 272, 'eventId': 676, 'period': 4,...
# 273  {'eventIdx': 273, 'eventId': 677, 'period': 4,...
# 274  {'eventIdx': 274, 'eventId': 678, 'period': 4,...
# 275  {'eventIdx': 275, 'eventId': 571, 'period': 4,...
# 276  {'eventIdx': 276, 'eventId': 679, 'period': 4,...
# 277  {'eventIdx': 277, 'eventId': 680, 'period': 4,...
# 278  {'eventIdx': 278, 'eventId': 573, 'period': 4,...
# 279  {'eventIdx': 279, 'eventId': 681, 'period': 4,...
# 280  {'eventIdx': 280, 'eventId': 682, 'period': 4,...
# 281  {'eventIdx': 281, 'eventId': 683, 'period': 4,...
# 282  {'eventIdx': 282, 'eventId': 574, 'period': 4,...
# 283  {'eventIdx': 283, 'eventId': 684, 'period': 4,...
# 284  {'eventIdx': 284, 'eventId': 685, 'period': 4,...
# 285  {'eventIdx': 285, 'eventId': 686, 'period': 4,...
# 286  {'eventIdx': 286, 'eventId': 687, 'period': 4,...
# 287  {'eventIdx': 287, 'eventId': 689, 'period': 4,...
# 288  {'eventIdx': 288, 'eventId': 575, 'period': 4,...
# 289  {'eventIdx': 289, 'eventId': 578, 'period': 4,...
# 290  {'eventIdx': 290, 'eventId': 579, 'period': 5,...
# 291  {'eventIdx': 291, 'eventId': 580, 'period': 5,...
# 292  {'eventIdx': 292, 'eventId': 690, 'period': 5,...
# 293  {'eventIdx': 293, 'eventId': 691, 'period': 5,...
# 294  {'eventIdx': 294, 'eventId': 692, 'period': 5,...
# 295  {'eventIdx': 295, 'eventId': 693, 'period': 5,...
# 296  {'eventIdx': 296, 'eventId': 694, 'period': 5,...
# 297  {'eventIdx': 297, 'eventId': 581, 'period': 5,...
# 298  {'eventIdx': 298, 'eventId': 584, 'period': 5,...
# 299  {'eventIdx': 299, 'eventId': 585, 'period': 5,...
#
#                   coordinates  \
# 0                          {}
# 1                          {}
# 2                          {}
# 3        {'x': 0.0, 'y': 0.0}
# 4     {'x': 66.0, 'y': -31.0}
# 5                          {}
# 6     {'x': 69.0, 'y': -22.0}
# 7      {'x': 43.0, 'y': 39.0}
# 8                          {}
# 9      {'x': 20.0, 'y': 22.0}
# 10    {'x': 89.0, 'y': -12.0}
# 11     {'x': 68.0, 'y': 10.0}
# 12     {'x': 50.0, 'y': 40.0}
# 13    {'x': 73.0, 'y': -14.0}
# 14   {'x': -90.0, 'y': -31.0}
# 15                         {}
# 16    {'x': -69.0, 'y': 22.0}
# 17    {'x': -59.0, 'y': 29.0}
# 18                         {}
# 19    {'x': -69.0, 'y': 22.0}
# 20     {'x': -72.0, 'y': 5.0}
# 21    {'x': 25.0, 'y': -29.0}
# 22     {'x': 58.0, 'y': -2.0}
# 23      {'x': 72.0, 'y': 9.0}
# 24                         {}
# 25     {'x': 69.0, 'y': 22.0}
# 26    {'x': -69.0, 'y': 27.0}
# 27    {'x': -76.0, 'y': -5.0}
# 28    {'x': -69.0, 'y': 13.0}
# 29     {'x': 74.0, 'y': 14.0}
# 30      {'x': 79.0, 'y': 5.0}
# 31      {'x': 83.0, 'y': 6.0}
# 32                         {}
# 33   {'x': -20.0, 'y': -22.0}
# 34     {'x': 49.0, 'y': 21.0}
# 35      {'x': 67.0, 'y': 8.0}
# 36     {'x': 47.0, 'y': 39.0}
# 37                         {}
# 38     {'x': 69.0, 'y': 22.0}
# 39     {'x': 98.0, 'y': 24.0}
# 40    {'x': -83.0, 'y': 40.0}
# 41   {'x': -37.0, 'y': -31.0}
# 42                         {}
# 43   {'x': -20.0, 'y': -22.0}
# 44    {'x': -67.0, 'y': 40.0}
# 45                         {}
# 46    {'x': -69.0, 'y': 22.0}
# 47    {'x': 99.0, 'y': -31.0}
# 48    {'x': 45.0, 'y': -11.0}
# 49     {'x': 72.0, 'y': 18.0}
# 50                         {}
# 51     {'x': 69.0, 'y': 22.0}
# 52     {'x': 42.0, 'y': 12.0}
# 53     {'x': 76.0, 'y': -7.0}
# 54                         {}
# 55    {'x': 69.0, 'y': -22.0}
# 56                         {}
# 57     {'x': 20.0, 'y': 22.0}
# 58    {'x': 68.0, 'y': -12.0}
# 59     {'x': 70.0, 'y': 12.0}
# 60       {'x': 0.0, 'y': 0.0}
# 61                         {}
# 62     {'x': 20.0, 'y': 22.0}
# 63    {'x': -97.0, 'y': -1.0}
# 64    {'x': -59.0, 'y': 23.0}
# 65    {'x': -17.0, 'y': 27.0}
# 66                         {}
# 67   {'x': -20.0, 'y': -22.0}
# 68                         {}
# 69       {'x': 0.0, 'y': 0.0}
# 70     {'x': 84.0, 'y': -8.0}
# 71    {'x': 70.0, 'y': -24.0}
# 72      {'x': 73.0, 'y': 4.0}
# 73   {'x': -77.0, 'y': -21.0}
# 74    {'x': -64.0, 'y': 40.0}
# 75   {'x': -46.0, 'y': -17.0}
# 76    {'x': -92.0, 'y': 38.0}
# 77   {'x': -80.0, 'y': -40.0}
# 78    {'x': -37.0, 'y': 27.0}
# 79     {'x': -79.0, 'y': 0.0}
# 80   {'x': -69.0, 'y': -22.0}
# 81     {'x': -62.0, 'y': 1.0}
# 82    {'x': -82.0, 'y': -7.0}
# 83   {'x': -89.0, 'y': -22.0}
# 84                         {}
# 85   {'x': -69.0, 'y': -22.0}
# 86   {'x': -66.0, 'y': -33.0}
# 87                         {}
# 88                         {}
# 89                         {}
# 90                         {}
# 91       {'x': 0.0, 'y': 0.0}
# 92                         {}
# 93    {'x': 20.0, 'y': -22.0}
# 94                         {}
# 95       {'x': 0.0, 'y': 0.0}
# 96   {'x': -73.0, 'y': -10.0}
# 97     {'x': 75.0, 'y': 14.0}
# 98     {'x': 72.0, 'y': 12.0}
# 99     {'x': 72.0, 'y': 12.0}
# 100    {'x': 78.0, 'y': -6.0}
# 101                        {}
# 102  {'x': -69.0, 'y': -22.0}
# 103  {'x': -80.0, 'y': -40.0}
# 104   {'x': -42.0, 'y': 30.0}
# 105                        {}
# 106   {'x': -69.0, 'y': 22.0}
# 107    {'x': 51.0, 'y': 30.0}
# 108                        {}
# 109    {'x': 69.0, 'y': 22.0}
# 110   {'x': -74.0, 'y': 10.0}
# 111  {'x': -54.0, 'y': -29.0}
# 112  {'x': -98.0, 'y': -26.0}
# 113    {'x': 54.0, 'y': 34.0}
# 114  {'x': -15.0, 'y': -40.0}
# 115   {'x': -38.0, 'y': 40.0}
# 116    {'x': -67.0, 'y': 6.0}
# 117    {'x': -70.0, 'y': 9.0}
# 118   {'x': 59.0, 'y': -42.0}
# 119  {'x': -62.0, 'y': -16.0}
# 120   {'x': -73.0, 'y': 41.0}
# 121    {'x': 96.0, 'y': 25.0}
# 122   {'x': 48.0, 'y': -14.0}
# 123                        {}
# 124   {'x': 69.0, 'y': -22.0}
# 125  {'x': -13.0, 'y': -20.0}
# 126  {'x': -69.0, 'y': -22.0}
# 127   {'x': -67.0, 'y': 19.0}
# 128                        {}
# 129   {'x': -69.0, 'y': 22.0}
# 130                        {}
# 131   {'x': -20.0, 'y': 22.0}
# 132    {'x': 75.0, 'y': 32.0}
# 133   {'x': -56.0, 'y': -8.0}
# 134                        {}
# 135  {'x': -69.0, 'y': -22.0}
# 136    {'x': -59.0, 'y': 8.0}
# 137   {'x': -37.0, 'y': -6.0}
# 138                        {}
# 139  {'x': -69.0, 'y': -22.0}
# 140   {'x': -69.0, 'y': 20.0}
# 141   {'x': -62.0, 'y': 36.0}
# 142   {'x': -59.0, 'y': 23.0}
# 143    {'x': -68.0, 'y': 8.0}
# 144    {'x': -67.0, 'y': 4.0}
# 145                        {}
# 146   {'x': -69.0, 'y': 22.0}
# 147  {'x': -22.0, 'y': -40.0}
# 148    {'x': -61.0, 'y': 3.0}
# 149    {'x': -68.0, 'y': 7.0}
# 150   {'x': -53.0, 'y': 16.0}
# 151    {'x': -58.0, 'y': 6.0}
# 152    {'x': 43.0, 'y': 18.0}
# 153    {'x': 63.0, 'y': -1.0}
# 154                        {}
# 155   {'x': 69.0, 'y': -22.0}
# 156   {'x': 99.0, 'y': -23.0}
# 157    {'x': 40.0, 'y': 25.0}
# 158     {'x': 66.0, 'y': 1.0}
# 159    {'x': 94.0, 'y': -8.0}
# 160                        {}
# 161                        {}
# 162                        {}
# 163                        {}
# 164      {'x': 0.0, 'y': 0.0}
# 165                        {}
# 166   {'x': -20.0, 'y': 22.0}
# 167     {'x': 51.0, 'y': 7.0}
# 168   {'x': 71.0, 'y': -16.0}
# 169  {'x': -12.0, 'y': -25.0}
# 170                        {}
# 171   {'x': -69.0, 'y': 22.0}
# 172     {'x': 65.0, 'y': 0.0}
# 173   {'x': 64.0, 'y': -40.0}
# 174   {'x': -69.0, 'y': 22.0}
# 175   {'x': -37.0, 'y': 18.0}
# 176   {'x': -55.0, 'y': 26.0}
# 177    {'x': -70.0, 'y': 1.0}
# 178      {'x': 0.0, 'y': 0.0}
# 179     {'x': 72.0, 'y': 9.0}
# 180   {'x': -51.0, 'y': 26.0}
# 181                        {}
# 182   {'x': -69.0, 'y': 22.0}
# 183                        {}
# 184    {'x': 69.0, 'y': 22.0}
# 185    {'x': 74.0, 'y': -8.0}
# 186                        {}
# 187   {'x': 69.0, 'y': -22.0}
# 188    {'x': 76.0, 'y': -7.0}
# 189                        {}
# 190   {'x': 69.0, 'y': -22.0}
# 191    {'x': 99.0, 'y': 10.0}
# 192                        {}
# 193   {'x': 69.0, 'y': -22.0}
# 194   {'x': -68.0, 'y': -8.0}
# 195  {'x': -69.0, 'y': -20.0}
# 196   {'x': -66.0, 'y': -2.0}
# 197    {'x': -72.0, 'y': 5.0}
# 198    {'x': -67.0, 'y': 7.0}
# 199   {'x': -34.0, 'y': 22.0}
# 200                        {}
# 201   {'x': -69.0, 'y': 22.0}
# 202  {'x': -42.0, 'y': -40.0}
# 203    {'x': 70.0, 'y': -6.0}
# 204     {'x': 54.0, 'y': 0.0}
# 205    {'x': 66.0, 'y': 10.0}
# 206    {'x': 69.0, 'y': 22.0}
# 207    {'x': 62.0, 'y': 32.0}
# 208      {'x': 0.0, 'y': 0.0}
# 209  {'x': -65.0, 'y': -25.0}
# 210                        {}
# 211   {'x': -20.0, 'y': 22.0}
# 212   {'x': 44.0, 'y': -17.0}
# 213    {'x': 72.0, 'y': -1.0}
# 214   {'x': 52.0, 'y': -25.0}
# 215    {'x': 66.0, 'y': -2.0}
# 216   {'x': -12.0, 'y': 39.0}
# 217                        {}
# 218    {'x': 20.0, 'y': 22.0}
# 219    {'x': 99.0, 'y': 13.0}
# 220     {'x': 68.0, 'y': 5.0}
# 221                        {}
# 222   {'x': 69.0, 'y': -22.0}
# 223     {'x': 76.0, 'y': 2.0}
# 224   {'x': 46.0, 'y': -12.0}
# 225                        {}
# 226   {'x': 69.0, 'y': -22.0}
# 227                        {}
# 228    {'x': 69.0, 'y': 22.0}
# 229   {'x': -84.0, 'y': 39.0}
# 230                        {}
# 231  {'x': -69.0, 'y': -22.0}
# 232    {'x': -64.0, 'y': 0.0}
# 233   {'x': -62.0, 'y': -3.0}
# 234    {'x': -53.0, 'y': 7.0}
# 235  {'x': -55.0, 'y': -12.0}
# 236                        {}
# 237  {'x': -69.0, 'y': -35.0}
# 238  {'x': -69.0, 'y': -22.0}
# 239  {'x': -64.0, 'y': -28.0}
# 240   {'x': -49.0, 'y': -3.0}
# 241    {'x': -61.0, 'y': 6.0}
# 242   {'x': -75.0, 'y': -8.0}
# 243   {'x': -57.0, 'y': 29.0}
# 244      {'x': 0.0, 'y': 0.0}
# 245  {'x': -88.0, 'y': -18.0}
# 246                        {}
# 247    {'x': 69.0, 'y': 22.0}
# 248    {'x': 67.0, 'y': -1.0}
# 249   {'x': 53.0, 'y': -32.0}
# 250    {'x': 84.0, 'y': -9.0}
# 251    {'x': 57.0, 'y': 31.0}
# 252                        {}
# 253    {'x': 69.0, 'y': 22.0}
# 254    {'x': 77.0, 'y': 11.0}
# 255                        {}
# 256   {'x': -20.0, 'y': 22.0}
# 257   {'x': 70.0, 'y': -12.0}
# 258                        {}
# 259                        {}
# 260                        {}
# 261                        {}
# 262      {'x': 0.0, 'y': 0.0}
# 263  {'x': -66.0, 'y': -20.0}
# 264   {'x': -50.0, 'y': 26.0}
# 265     {'x': 57.0, 'y': 1.0}
# 266                        {}
# 267   {'x': 69.0, 'y': -22.0}
# 268     {'x': 75.0, 'y': 1.0}
# 269    {'x': 82.0, 'y': -2.0}
# 270    {'x': -74.0, 'y': 6.0}
# 271                        {}
# 272   {'x': -69.0, 'y': 22.0}
# 273     {'x': 78.0, 'y': 7.0}
# 274  {'x': -82.0, 'y': -16.0}
# 275   {'x': -81.0, 'y': -9.0}
# 276  {'x': -69.0, 'y': -22.0}
# 277  {'x': -45.0, 'y': -15.0}
# 278                        {}
# 279  {'x': -69.0, 'y': -22.0}
# 280   {'x': -73.0, 'y': -8.0}
# 281   {'x': -67.0, 'y': 17.0}
# 282                        {}
# 283   {'x': -69.0, 'y': 22.0}
# 284   {'x': -64.0, 'y': 21.0}
# 285    {'x': -73.0, 'y': 8.0}
# 286  {'x': -63.0, 'y': -27.0}
# 287   {'x': -76.0, 'y': 17.0}
# 288                        {}
# 289                        {}
# 290                        {}
# 291                        {}
# 292     {'x': 76.0, 'y': 1.0}
# 293   {'x': -73.0, 'y': -5.0}
# 294    {'x': 68.0, 'y': -3.0}
# 295    {'x': -68.0, 'y': 5.0}
# 296                        {}
# 297                        {}
# 298                        {}
# 299                        {}
#
#                                                players  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    [{'player': {'id': 8476897, 'fullName': 'Oskar...
# 4    [{'player': {'id': 8474102, 'fullName': 'David...
# 5                                                  NaN
# 6    [{'player': {'id': 8477500, 'fullName': 'Bo Ho...
# 7    [{'player': {'id': 8474568, 'fullName': 'Luke ...
# 8                                                  NaN
# 9    [{'player': {'id': 8475158, 'fullName': 'Ryan ...
# 10   [{'player': {'id': 8475170, 'fullName': 'Brayd...
# 11   [{'player': {'id': 8475765, 'fullName': 'Vladi...
# 12   [{'player': {'id': 8476441, 'fullName': 'Joel ...
# 13   [{'player': {'id': 8481479, 'fullName': 'Broga...
# 14   [{'player': {'id': 8474565, 'fullName': 'Alex ...
# 15                                                 NaN
# 16   [{'player': {'id': 8476897, 'fullName': 'Oskar...
# 17   [{'player': {'id': 8476410, 'fullName': 'Josh ...
# 18                                                 NaN
# 19   [{'player': {'id': 8476897, 'fullName': 'Oskar...
# 20   [{'player': {'id': 8476441, 'fullName': 'Joel ...
# 21   [{'player': {'id': 8475158, 'fullName': 'Ryan ...
# 22   [{'player': {'id': 8476441, 'fullName': 'Joel ...
# 23   [{'player': {'id': 8471303, 'fullName': 'Alexa...
# 24                                                 NaN
# 25   [{'player': {'id': 8470257, 'fullName': 'Alexa...
# 26   [{'player': {'id': 8477213, 'fullName': 'Tim S...
# 27   [{'player': {'id': 8477482, 'fullName': 'Zach ...
# 28   [{'player': {'id': 8474565, 'fullName': 'Alex ...
# 29   [{'player': {'id': 8475768, 'fullName': 'Jaden...
# 30   [{'player': {'id': 8474102, 'fullName': 'David...
# 31   [{'player': {'id': 8474568, 'fullName': 'Luke ...
# 32                                                 NaN
# 33   [{'player': {'id': 8474291, 'fullName': 'Jay B...
# 34   [{'player': {'id': 8480012, 'fullName': 'Elias...
# 35   [{'player': {'id': 8477482, 'fullName': 'Zach ...
# 36   [{'player': {'id': 8474568, 'fullName': 'Luke ...
# 37                                                 NaN
# 38   [{'player': {'id': 8480023, 'fullName': 'Rober...
# 39   [{'player': {'id': 8480800, 'fullName': 'Quinn...
# 40   [{'player': {'id': 8476441, 'fullName': 'Joel ...
# 41   [{'player': {'id': 8480800, 'fullName': 'Quinn...
# 42                                                 NaN
# 43   [{'player': {'id': 8474291, 'fullName': 'Jay B...
# 44   [{'player': {'id': 8477213, 'fullName': 'Tim S...
# 45                                                 NaN
# 46   [{'player': {'id': 8476897, 'fullName': 'Oskar...
# 47   [{'player': {'id': 8477937, 'fullName': 'Jake ...
# 48   [{'player': {'id': 8480012, 'fullName': 'Elias...
# 49   [{'player': {'id': 8475158, 'fullName': 'Ryan ...
# 50                                                 NaN
# 51   [{'player': {'id': 8475170, 'fullName': 'Brayd...
# 52   [{'player': {'id': 8474125, 'fullName': 'Carl ...
# ...
# 20   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 21   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 22   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 23   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 24                                                 NaN
# 25   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 26   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 27   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 28   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 29   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 30   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 31   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 32                                                 NaN
# 33   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 34   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 35   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 36   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 37                                                 NaN
# 38   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 39   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 40   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 41   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 42                                                 NaN
# 43   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 44   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 45                                                 NaN
# 46   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 47   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 48   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 49   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 50                                                 NaN
# 51   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 52   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 53   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 54                                                 NaN
# 55   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 56                                                 NaN
# 57   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 58   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 59   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 60   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 61                                                 NaN
# 62   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 63   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 64   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 65   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 66                                                 NaN
# 67   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 68                                                 NaN
# 69   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 70   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 71   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 72   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 73   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 74   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 75   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 76   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 77   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 78   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 79   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 80   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 81   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 82   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 83   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 84                                                 NaN
# 85   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 86   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 87                                                 NaN
# 88                                                 NaN
# 89                                                 NaN
# 90                                                 NaN
# 91   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 92                                                 NaN
# 93   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 94                                                 NaN
# 95   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 96   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 97   {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 98   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 99   {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 100  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 101                                                NaN
# 102  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 103  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 104  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 105                                                NaN
# 106  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 107  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 108                                                NaN
# 109  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 110  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 111  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 112  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 113  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 114  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 115  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 116  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 117  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 118  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 119  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 120  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 121  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 122  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 123                                                NaN
# 124  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 125  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 126  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 127  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 128                                                NaN
# 129  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 130                                                NaN
# 131  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 132  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 133  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 134                                                NaN
# 135  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 136  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 137  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 138                                                NaN
# 139  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 140  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 141  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 142  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 143  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 144  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 145                                                NaN
# 146  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 147  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 148  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 149  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 150  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 151  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 152  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 153  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 154                                                NaN
# 155  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 156  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 157  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 158  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 159  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 160                                                NaN
# 161                                                NaN
# 162                                                NaN
# 163                                                NaN
# 164  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 165                                                NaN
# 166  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 167  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 168  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 169  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 170                                                NaN
# 171  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 172  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 173  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 174  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 175  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 176  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 177  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 178  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 179  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 180  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 181                                                NaN
# 182  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 183                                                NaN
# 184  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 185  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 186                                                NaN
# 187  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 188  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 189                                                NaN
# 190  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 191  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 192                                                NaN
# 193  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 194  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 195  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 196  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 197  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 198  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 199  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 200                                                NaN
# 201  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 202  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 203  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 204  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 205  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 206  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 207  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 208  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 209  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 210                                                NaN
# 211  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 212  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 213  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 214  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 215  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 216  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 217                                                NaN
# 218  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 219  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 220  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 221                                                NaN
# 222  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 223  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 224  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 225                                                NaN
# 226  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 227                                                NaN
# 228  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 229  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 230                                                NaN
# 231  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 232  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 233  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 234  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 235  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 236                                                NaN
# 237  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 238  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 239  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 240  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 241  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 242  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 243  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 244  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 245  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 246                                                NaN
# 247  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 248  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 249  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 250  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 251  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 252                                                NaN
# 253  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 254  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 255                                                NaN
# 256  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 257  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 258                                                NaN
# 259                                                NaN
# 260                                                NaN
# 261                                                NaN
# 262  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 263  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 264  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 265  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 266                                                NaN
# 267  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 268  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 269  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 270  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 271                                                NaN
# 272  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 273  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 274  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 275  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 276  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 277  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 278                                                NaN
# 279  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 280  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 281  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 282                                                NaN
# 283  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 284  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 285  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 286  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 287  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 288                                                NaN
# 289                                                NaN
# 290                                                NaN
# 291                                                NaN
# 292  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 293  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 294  {'id': 19, 'name': 'St. Louis Blues', 'link': ...
# 295  {'id': 23, 'name': 'Vancouver Canucks', 'link'...
# 296                                                NaN
# 297                                                NaN
# 298                                                NaN
# 299                                                NaN

# %%
# Get the total number of shots made by the player
player_total_shots = len(player_data['Shot']['x']) + len(player_data['Goal']['x'])
player_total_shots
# Out:
# 215

# %%
player_data_normalized = player_data
for i, x in enumerate(player_data_normalized['Shot']['x']):
    if x < 0:
        player_data_normalized['Shot']['x'][i] = player_data_normalized['Shot']['x'][i] * -1
        player_data_normalized['Shot']['y'][i] = player_data_normalized['Shot']['y'][i] * -1
        
for i, x in enumerate(player_data_normalized['Goal']['x']):
    if x < 0:
        player_data_normalized['Goal']['x'][i] = player_data_normalized['Goal']['x'][i] * -1
        player_data_normalized['Goal']['y'][i] = player_data_normalized['Goal']['y'][i] * -1

player_data_normalized == player_data
# Out:
# True

# %%
# Find the players goal score percentage
player_goal_pct = len(player_data['Goal']['x'])/player_total_shots
player_goal_pct
# Out:
# 0.13023255813953488

# %%
# To keep the aspect ration correct we use a square figure size
xbnds = np.array([-100.,100.0])
ybnds = np.array([-100,100])
extent = [xbnds[0],xbnds[1],ybnds[0],ybnds[1]]
# We are going to bin in 30 unit increments.  It is fun to play with this!  
gridsize= 30;mincnt=0

# %%
fig, ax = plt.subplots()
img = plt.imread("rink.png")
ax.imshow(img, extent = [0, 100, -42.5, 42.5])
plt.scatter(player_data['Shot']['x'], player_data['Shot']["y"], c = "red")
plt.scatter(player_data['Goal']['x'], player_data['Goal']["y"], c = "red")
plt.title(f"Shots of {full_name}")
plt.show()

fig, ax = plt.subplots()
img = plt.imread("rink.png")
ax.imshow(img, extent = [0, 100, -42.5, 42.5])
plt.scatter(player_data['Goal']['x'], player_data['Goal']["y"], c = "green")
plt.title(f"Goals of {full_name}")
plt.show()

# %%
sns.jointplot(x="x", y="y", data=player_data_normalized['Shot'],kind="kde")
sns.jointplot(x="x", y="y", data=player_data_normalized['Goal'],kind="kde")
